# %%
import cnvpytor

view = cnvpytor.Viewer(["file.pytor"], params={} )
reference_genome["chromosomes"].items()
view.bin_size = 100000

# %%
view.rd_use_mask = True # Use P mask to reduce noise
view.markersize = 0.5
view.rd_manhattan_range = [0, 4]
view.chrom = ['1']

view.global_plot()

# %%
view.panels = ['rd', 'snp']
view.global_plot()
